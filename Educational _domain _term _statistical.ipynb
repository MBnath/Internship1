# %%
import nltk
from collections import Counter

nltk.download('punkt')

# Function to read text from a file
def read_text_from_file(filename):
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

# Function to find term frequency statistics for specified words
def find_word_statistics(text, words_of_interest):
    words = nltk.word_tokenize(text)
    word_counts = Counter(words)
    word_statistics = {word: word_counts.get(word, 0) + 1 for word in words_of_interest}
    return word_statistics

# File path
file_path = 'Education.txt'  #  file path

# Read text from file
text = read_text_from_file(file_path)

# Specify the words you want to find statistics for
words_of_domain = ['అంగనం','అడుగు', 
 'అత్మ', 
 'అనుభవం', 
 'అనువర్తన ',
 'అమృతం ',
 'ఆకాశం ',
 'ఆత్మ ',
 'ఆదరణ' ,
 'ఆనందం', 
 'ఆపత్కాలం', 
 'ఆపరంగన ',
 'ఆరోగ్యం ',
 'ఆలయం ',
 'ఆవృత్తి ',
 'ఉదాహరణ' ,
 'ఉద్ఘాటన ',
 'ఉద్దీపన ',
 'ఉద్దేశం ',
 'ఉద్యమం', 
 'ఉపకరణం' ,
 'ఉపాయం ',
 'ఉపాయం ',
 'కళా ',
 'కళ్ళు ',
 'కాలము ',
 'కేంద్రం ',
 'కోణము ',
 'కోరిక ',
 'ఖగోళశాస్త్రం' ,
 'గణితం ',
 'గాలి ',
 'గోచి ',
 'గోపురం' ,
 'చక్రం ',
 'చేతి ',
 'ఛాయ', 
 'జాబితా' ,
 'జాలి ',
 'జ్ఞానం ',
 'జ్ఞాపకం ',
 'జ్యోతి ',
 'తాళం ',
 'తేజస్వి ',
 'తేలిక ',
 'తోట ',
 'దృష్టి ',
 'దేవాలయం', 
 'దేవుడు ',
 'ద్వారం ',
 'ద్వితీయ ',
 'ధన్యవాదం ',
 'ధర్మం ',
 'ధార ',
 'నకలు ',
 'నది ',
 'నిగమం', 
 'నియమం',
 'నిర్మాణం ',
 'నేతా ',
 'నేతృత్వం', 
 'నేతృత్వం ',
 'పంచాంగం ',
 'పండగ ',
 'పథకం ',
 'పరిపాలన ',
 'పరిశ్రమ ',
 'పాఠశాల ',
 'పారాయణ ',
 'పుస్తకం ',
 'పేరు ',
 'ప్రకారం', 
 'ప్రకృతి ',
 'ప్రతిష్ఠానం', 
 'ప్రపంచం ',
 'ప్రయాణం ',
 'ప్రవాహం ',
 'ప్రవృత్తి ',
 'ప్రాణం ',
 'ప్రేమ ',
 'బంధువు', 
 'బాధకం ',
 'బాల ',
 'బాల్యం', 
 'బీజం ',
 'భద్రం ',
 'భావన ',
 'భూమి ',
 'భూలోకం', 
 'మహిమ' ,
 'మహిళ' ,
 'వాణి ',
 'వారసత్వం', 
 'విద్య', 
 'శక్తి ',
 'శాంతి ',
 'సంతోషం ',
 'సహజం ',
 'సహజవాదం ',
 'సహజసౌందర్యం', 
 'సహజీవనం', 
 'సహాయం ',
 'సాగరం ',
 'సాధన ',
 'సాధుత్వం ',
 'సాహిత్యం ',
 'సౌందర్యం ',
 'స్వతంత్రం']

# Find word frequency statistics for specified words
word_statistics = find_word_statistics(text, words_of_domain)

# Print the statistics
print("Serial\tWord\t\tFrequency")
print("------------------------")
count = 1
for word, frequency in word_statistics.items():
    print(f"{count}\t{word}\t\t{frequency}")
    count += 1
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\BADRINATH\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Serial	Word		Frequency
# ------------------------
# 1	అంగనం		1
# 2	అడుగు		5
# 3	అత్మ		1
# 4	అనుభవం		7
# 5	అనువర్తన 		1
# 6	అమృతం 		1
# 7	ఆకాశం 		1
# 8	ఆత్మ 		1
# 9	ఆదరణ		5
# 10	ఆనందం		8
# 11	ఆపత్కాలం		1
# 12	ఆపరంగన 		1
# 13	ఆరోగ్యం 		1
# 14	ఆలయం 		1
# 15	ఆవృత్తి 		1
# 16	ఉదాహరణ		11
# 17	ఉద్ఘాటన 		1
# 18	ఉద్దీపన 		1
# 19	ఉద్దేశం 		1
# 20	ఉద్యమం		41
# 21	ఉపకరణం		1
# 22	ఉపాయం 		1
# 23	కళా 		1
# 24	కళ్ళు 		1
# 25	కాలము 		1
# 26	కేంద్రం 		1
# 27	కోణము 		1
# 28	కోరిక 		1
# 29	ఖగోళశాస్త్రం		3
# 30	గణితం 		1
# 31	గాలి 		1
# 32	గోచి 		1
# 33	గోపురం		2
# 34	చక్రం 		1
# 35	చేతి 		1
# 36	ఛాయ		1
# 37	జాబితా		18
# 38	జాలి 		1
# 39	జ్ఞానం 		1
# 40	జ్ఞాపకం 		1
# 41	జ్యోతి 		1
# 42	తాళం 		1
# 43	తేజస్వి 		1
# 44	తేలిక 		1
# 45	తోట 		1
# 46	దృష్టి 		1
# 47	దేవాలయం		11
# 48	దేవుడు 		1
# 49	ద్వారం 		1
# 50	ద్వితీయ 		1
# 51	ధన్యవాదం 		1
# ...
